# %% [markdown]
# # Set-up
# Install and import packages

# %%
import pandas as pd

# %% [markdown]
# # Get Data
# Import the csv file

# %%
data = pd.read_csv("data.csv")

# %% [markdown]
# # Data Analysis

# %%
display(data)
# Out:
#    1  2
# 0  3  4
# 1  5  6
